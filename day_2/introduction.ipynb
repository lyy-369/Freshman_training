# %% [markdown]
# ## jupyter notebook

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ## markdown 语法

# %% [markdown]
# ## markdown 语法

# %% [markdown]
# **markdown 语法介绍**
#
# # 一级标题
#
# ###### 六级标题
#
# [课题组github主页](https://github.com/wuaipinglab)
#
# ![workflow](./Co-infection/github/SARS-CoV-2_co-infection/img/workflow.jpg)

# %% [markdown]
# **markdown 语法介绍**
#
# # 一级标题
#
# ###### 六级标题
#
# [课题组github主页](https://github.com/wuaipinglab)
#
# ![workflow](./Co-infection/github/SARS-CoV-2_co-infection/img/workflow.jpg)

# %% [markdown]
# ## 支持LaTex 用来加入数学公式
#
# $$\begin{array}{*{20}{l}}
# {P{ \left( {X=k} \left) =\frac{{C\mathop{{}}\nolimits_{{M}}^{{k}}C\mathop{{}}\nolimits_{{N-M}}^{{n-k}}}}{{C\mathop{{}}\nolimits_{{N}}^{{n}}}}\right. \right. }}\\
# { \left( {k=0,1,2, \cdots m,m=\text{m}\text{i}\text{n}{ \left\{ {M,m} \right\} },n \le N,M \le N,n\text{、}M\text{、}N \in NaNundefined} \right) }
# \end{array}$$
#
# [LaTeX数学公式-详细教程](https://blog.csdn.net/NSJim/article/details/109045914)

# %% [markdown]
# ## 支持LaTex 用来加入数学公式
#
# $$\begin{array}{*{20}{l}}
# {P{ \left( {X=k} \left) =\frac{{C\mathop{{}}\nolimits_{{M}}^{{k}}C\mathop{{}}\nolimits_{{N-M}}^{{n-k}}}}{{C\mathop{{}}\nolimits_{{N}}^{{n}}}}\right. \right. }}\\
# { \left( {k=0,1,2, \cdots m,m=\text{m}\text{i}\text{n}{ \left\{ {M,m} \right\} },n \le N,M \le N,n\text{、}M\text{、}N \in NaNundefined} \right) }
# \end{array}$$
#
# [LaTeX数学公式-详细教程](https://blog.csdn.net/NSJim/article/details/109045914)

# %% [markdown]
# ## 快捷键
#
# ### 帮助-快捷键 （按H键）

# %%
import pandas as pd

variant_surveillance_path = '/home/wap/Co-infection/Data_20220504/data/variant_surveillance.tsv'

df = pd.read_csv(variant_surveillance_path, delimiter='\t').dropna(axis=0, subset=['AA Substitutions', 'Pango lineage'])
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3134: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_test = df[1000:1050]
df_test
# Out:
#           Accession ID             Type Clade Pango lineage Pangolin version  \
# 1000   EPI_ISL_3870838  betacoronavirus    GK         AY.29      PLEARN-v1.6
# 1001   EPI_ISL_3870839  betacoronavirus    GK         AY.29      PLEARN-v1.6
# 1002   EPI_ISL_3870840  betacoronavirus    GK         AY.29      PLEARN-v1.6
# 1003   EPI_ISL_3870841  betacoronavirus    GK         AY.29      PLEARN-v1.6
# 1004   EPI_ISL_2970593  betacoronavirus    GH         B.1.2      PLEARN-v1.6
# 1005   EPI_ISL_3870842  betacoronavirus    GR       B.1.1.7      PLEARN-v1.6
# 1006   EPI_ISL_3870843  betacoronavirus    GR       B.1.1.7      PLEARN-v1.6
# 1007   EPI_ISL_3870844  betacoronavirus    GR       B.1.1.7      PLEARN-v1.6
# 1008   EPI_ISL_3870845  betacoronavirus    GR       B.1.1.7      PLEARN-v1.6
# 1009   EPI_ISL_3870846  betacoronavirus    GR       B.1.1.7      PLEARN-v1.6
# 1010   EPI_ISL_3870848  betacoronavirus    GK         AY.29      PLEARN-v1.6
# ...

# %%
df_test.columns
# Out:
# Index(['Accession ID', 'Type', 'Clade', 'Pango lineage', 'Pangolin version',
#        'AA Substitutions', 'Variant', 'Collection date', 'Location', 'Host',
#        'Submission date', 'Is reference?', 'Is complete?', 'Is high coverage?',
#        'Is low coverage?', 'N-Content', 'GC-Content', 'Sequence length'],
#       dtype='object')

# %%
df_test['Pango lineage'].value_counts()
# Out:
# AY.29      22
# B.1.1.7    12
# AY.29.1     5
# AY.44       3
# AY.38       2
# BA.2.3      1
# AY.4.5      1
# AY.125      1
# AY.47       1
# AY.25       1
# B.1.2       1
# Name: Pango lineage, dtype: int64

# %%
df_test['AA Substitutions'].to_dict()
# Out:
# {1000: '(N_G215C,Spike_T95I,N_D63G,N_R203M,NSP12_G671S,Spike_G142D,NS3_S26L,Spike_P681R,Spike_R158del,NSP3_P1228L,NSP3_V932A,NS7a_V82A,NSP3_A488S,Spike_F157del,NSP4_T492I,NSP14_A394V,Spike_T19R,NS7a_T120I,N_D377Y,M_I82T,Spike_D950N,NS7b_T40I,NSP13_P77L,Spike_E156G,NSP3_P1469S,Spike_T478K,NSP6_T77A,NSP12_P323L,Spike_D614G,NSP4_V167L,Spike_L452R)',
#  1001: '(N_G215C,Spike_T95I,N_D63G,N_R203M,NSP12_G671S,Spike_G142D,NS3_S26L,Spike_P681R,NSP15_D39Y,Spike_R158del,NSP3_P1228L,NSP3_V932A,NS7a_V82A,NSP3_A488S,Spike_F157del,NSP4_T492I,NSP14_A394V,Spike_T19R,NS7a_T120I,N_D377Y,M_I82T,Spike_D950N,NS7b_T40I,NSP13_P77L,Spike_E156G,NSP3_P1469S,Spike_T478K,NSP12_L638F,NSP6_T77A,NSP12_P323L,Spike_D614G,NSP4_V167L,Spike_L452R)',
# ...

# %%
df_test['Submission date'].sort_values()
# Out:
# 1004    2021-07-16
# 1023    2021-08-26
# 1027    2021-09-02
# 1028    2021-09-02
# 1029    2021-09-02
# 1030    2021-09-02
# 1031    2021-09-02
# 1032    2021-09-02
# 1033    2021-09-02
# 1034    2021-09-02
# 1035    2021-09-02
# 1036    2021-09-02
# 1000    2021-09-02
# 1039    2021-09-02
# 1040    2021-09-02
# 1041    2021-09-02
# 1042    2021-09-02
# 1043    2021-09-02
# 1044    2021-09-02
# 1045    2021-09-02
# 1046    2021-09-02
# 1047    2021-09-02
# 1025    2021-09-02
# 1038    2021-09-02
# 1024    2021-09-02
# 1049    2021-09-02
# 1009    2021-09-02
# 1010    2021-09-02
# 1011    2021-09-02
# 1048    2021-09-02
# 1012    2021-09-02
# 1013    2021-09-02
# 1014    2021-09-02
# 1015    2021-09-02
# 1016    2021-09-02
# 1017    2021-09-02
# 1006    2021-09-02
# 1005    2021-09-02
# 1003    2021-09-02
# 1002    2021-09-02
# 1001    2021-09-02
# 1008    2021-09-02
# 1007    2021-09-02
# 1022    2021-09-21
# 1019    2021-09-21
# 1020    2021-09-21
# 1021    2021-09-21
# ...

# %% [markdown]
# ## 任务
#
# ### 提取SARS-CoV-2 样本占比大于万分之一的各lineage 75%和10%水平的特征突变，以及mutation的总数
#
# ### lineage 75%和10%水平的特征突变：该lineage 75%和10%以上的毒株都具有的突变
